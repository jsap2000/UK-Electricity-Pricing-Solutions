# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

EURGAS = pd.read_excel(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\GasStorageEurope.xlsx", sheet_name="WGV and No by status")



# Select the rows data should be taken from
EURGAS = EURGAS.iloc[:,0:5].copy()
EURGAS = EURGAS.round(2)
EURGAS = EURGAS.replace(np.NaN, 0)

print(EURGAS.to_string())
# Out:
#    Country / Status / WGV (TWh)  operational  under construction  planned    TOTAL
# 0                       Austria        95.19                0.00     0.00    95.19
# 1                       Belgium         9.00                0.00     0.00     9.00
# 2                      Bulgaria         5.80                0.00     4.75    10.55
# 3                       Croatia         5.22                0.00     0.28     5.50
# 4                Czech Republic        43.13                0.84     0.43    44.41
# 5                       Denmark        10.46                0.00     0.00    10.46
# 6                        France       132.30                0.00     4.10   136.40
# 7                       Germany       260.53                0.00     5.90   266.42
# 8                        Greece         0.00                0.00     3.86     3.86
# 9                       Hungary        69.63                0.00     0.00    69.63
# 10                        Italy       195.37                8.59    40.75   244.70
# 11                       Latvia        24.20                0.00     0.00    24.20
# 12                  Netherlands       144.56                0.00     0.00   144.56
# 13                       Poland        38.43                0.69     9.00    48.12
# 14                     Portugal         3.57                0.00     0.00     3.57
# 15                      Romania        32.99                0.00    12.53    45.52
# 16                     Slovakia        43.45                0.00     3.61    47.05
# 17                        Spain        34.25                0.00     0.00    34.25
# 18                       Sweden         0.09                0.00     0.00     0.09
# 19                           EU      1148.16               10.12    85.21  1243.48
# 20                      Belarus        15.32                5.52     0.00    20.83
# 21           Russian Federation        23.82                0.00     0.00    23.82
# 22                       Serbia         4.53                0.00     0.00     4.53
# 23                       Turkey        35.02                0.00    43.24    78.26
# 24                      Ukraine       327.92                0.00     0.00   327.92
# 25               United Kingdom        17.47                0.38    35.34    53.19
# 26                 Total non EU       424.09                5.89    78.58   508.56
# 27                 TOTAL EUROPE      1572.25               16.01   163.79  1752.05

# %%
#EMix.loc[EURGAS["Country / Status / WGV (TWh)"] == "United Kingdom"].loc[EMix["Year"] == 2021].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Unit"] == "TWh"]

GBop = EURGAS.iloc[25,1]
NLop = EURGAS.iloc[12,1]
BEop = EURGAS.iloc[1,1]
FRop = EURGAS.iloc[6,1]
DEop = EURGAS.iloc[7,1]
ITop = EURGAS.iloc[10,1]

GBuc = EURGAS.iloc[25,2]
NLuc = EURGAS.iloc[12,2]
BEuc = EURGAS.iloc[1,2]
FRuc = EURGAS.iloc[6,2]
DEuc = EURGAS.iloc[7,2]
ITuc = EURGAS.iloc[10,2]

GBpl = EURGAS.iloc[25,3]
NLpl = EURGAS.iloc[12,3]
BEpl = EURGAS.iloc[1,3]
FRpl = EURGAS.iloc[6,3]
DEpl = EURGAS.iloc[7,3]
ITpl = EURGAS.iloc[10,3]

n_BZN = 4
Country = np.array(["United Kingdom", "Belgium", "Netherlands", "France", "Germany", "Italy"])
op = np.array([GBop, BEop, NLop, FRop, DEop, ITop])
uc = np.array([GBuc, BEuc, NLuc, FRuc, DEuc, ITuc])
pl = np.array([GBpl, BEpl, NLpl, FRpl, DEpl, ITpl])

# create plot
fig, ax = plt.subplots()
fig.set_figheight(4)
fig.set_figwidth(7)

#index = np.arange(n_BZN)
bar_width = 0.2
opacity = 0.8

plt.bar(Country, op, color='darkblue', label='Operational')
plt.bar(Country, uc, bottom=op, color='mediumblue', label='Under Construction')
plt.bar(Country, pl, bottom=op+uc, color='lightblue', label='Planned')

plt.ylabel("Working Gas Volume Equivalent [TWh]")
plt.title("Gaseous Natural Gas Storage Capacity Jul. 2021")

plt.legend()

plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')
plt.ylim(0, 300)

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

plt.tight_layout()
plt.show()

# %%
EURLNG = pd.read_excel(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\LNGStorageEurope.xlsx", sheet_name="Import Terminals")

EURLNGSt = pd.DataFrame()

# Select the rows data should be taken from
EURLNGSt["Country"] = EURLNG.iloc[2:72,0]
EURLNGSt["Status"] = EURLNG.iloc[2:72,3]
EURLNGSt["Commenced"] = EURLNG.iloc[2:72,5]
EURLNGSt["Type"] = EURLNG.iloc[2:72,6]
EURLNGSt["Storage [m3]"] = EURLNG.iloc[2:72,11]
#EURLNGSt = EURLNG.round(2)

EURLNGSt = EURLNGSt.replace(np.NaN, 0)
EURLNGSt = EURLNGSt.reset_index()
del EURLNGSt["index"]

print(EURLNGSt.to_string())
# Out:
#            Country                 Status Commenced                                    Type   Storage [m3]
# 0          Albania                planned      2023                                    FSRU              0
# 1          Belgium            operational      1987                           large onshore         566000
# 2          Belgium     under construction      2024                           large onshore              0
# 3          Belgium     under construction      2026                           large onshore              0
# 4          Croatia            operational      2021                                    FSRU         140000
# 5          Croatia                planned      2029                                    FSRU         140000
# 6           Cyprus     under construction      2023                                    FSRU         137000
# 7            Egypt              suspended         w                                    FSRU              0
# 8            Egypt            operational      2015                                    FSRU         170000
# 9          Estonia                planned      2025                           large onshore         160000
# 10         Estonia                planned         0                           large onshore         160000
# 11         Finland                planned      2023                                    FSRU         151000
# 12          France            operational      2016                           large onshore         600000
# 13          France            operational      2010                           large onshore         330000
# 14          France                planned      2022                           large onshore              0
# 15          France                planned      2030                           large onshore              0
# 16          France            operational      1972                           large onshore          80000
# 17          France            operational      1980                           large onshore         360000
# 18          France                planned         0                                    FSRU              0
# 19         Germany                planned      2023                           large onshore         330000
# 20         Germany                planned      2026                           large onshore  up to 480 000
# 21         Germany                planned      2023                                    FSRU         263000
# 22         Germany                planned      2025                                    FSRU              0
# 23         Germany                planned      2023                                    FSRU         170000
# 24          Greece                planned      2023                                    FSRU              0
# 25          Greece     under construction      2023                                    FSRU         153500
# 26          Greece                planned         0                                    FSRU         170000
# 27          Greece            operational      1999                           large onshore         225000
# 28          Greece                planned      2024                                    FSRU         170000
# 29         Ireland                planned         0                                    FSRU              0
# 30         Ireland                planned      2024                                    FSRU              0
# 31          Israel            operational      2013                                    FSRU         138000
# 32           Italy            operational      2013                                    FSRU         137500
# 33           Italy            operational      1971                           large onshore         100000
# 34           Italy                planned      2023                                    FSRU              0
# 35           Italy                planned      2024                                    FSRU              0
# 36           Italy                planned         0                           large onshore         320000
# 37           Italy            operational      2009  offshore GBS (Gravity Based Structure)         250000
# 38          Latvia                planned      2023                FRU + direct link to UGS              0
# 39       Lithuania            operational      2014                                    FSRU         170000
# 40           Malta            operational      2017            FSU + onshore regasification         125000
# 41         Morocco                planned         0                           large onshore              0
# 42         Morocco                planned      2025                                    FSRU              0
# 43     Netherlands            operational      2011                           large onshore         540000
# 44     Netherlands     under construction      2023                           large onshore              0
# 45     Netherlands                planned      2025                           large onshore         180000
# 46     Netherlands            operational      2022                                    FSRU         180000
# 47          Poland                planned      2025                                    FSRU         170000
# 48          Poland            operational      2016                           large onshore         320000
# 49          Poland     under construction      2023                           large onshore         180000
# 50        Portugal            operational      2004                           large onshore         390000
# 51          Russia            operational      2019                                    FSRU              0
# 52           Spain            operational      1969                           large onshore         760000
# 53           Spain            operational      2003                           large onshore         450000
# 54           Spain            operational      1989                           large onshore         587000
# 55           Spain  built not operational      2012                           large onshore         300000
# 56           Spain            operational      1988                           large onshore         619500
# 57           Spain            operational      2007                           large onshore         300000
# 58           Spain            operational      2006                           large onshore         600000
# 59          Turkey            operational      2016                                    FSRU         167000
# 60          Turkey            operational      2006                           large onshore         280000
# 61          Turkey                planned      2022                                    FSRU         170000
# 62          Turkey            operational      2018                                    FSRU         170000
# 63          Turkey            operational      1994                           large onshore         255000
# 64  United Kingdom            operational      2005                           large onshore        1000000
# 65  United Kingdom     under construction      2025                           large onshore         200000
# 66  United Kingdom            operational      2009                           large onshore         320000
# 67  United Kingdom            operational      2009                           large onshore         775000
# 68  United Kingdom              suspended      2007                                gas port              0

# %%
#EMix.loc[EURLNGSt["Country / Status / WGV (TWh)"] == "United Kingdom"].loc[EMix["Year"] == 2021].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Unit"] == "TWh"]

GBoplLNGNG = EURLNGSt.iloc[64,4] + EURLNGSt.iloc[66,4] + EURLNGSt.iloc[67,4]
NLoplLNGNG = EURLNGSt.iloc[43,4] + EURLNGSt.iloc[46,4]
BEoplLNGNG = EURLNGSt.iloc[1,4]
FRoplLNGNG = EURLNGSt.iloc[12,4] + EURLNGSt.iloc[13,4] + EURLNGSt.iloc[16,4] + EURLNGSt.iloc[17,4]
DEoplLNGNG = 0
IToplLNGNG = EURLNGSt.iloc[32,4] + EURLNGSt.iloc[33,4] + EURLNGSt.iloc[37,4]

GBucLNG = EURLNGSt.iloc[65,4]
NLucLNG = EURLNGSt.iloc[44,4]
BEucLNG = EURLNGSt.iloc[2,4] + EURLNGSt.iloc[3,4]
FRucLNG = 0
DEucLNG = 0
ITucLNG = 0

GBplLNG = 0
NLplLNG = EURLNGSt.iloc[45,4]
BEplLNG = 0
FRplLNG = EURLNGSt.iloc[14,4] + EURLNGSt.iloc[15,4]
DEplLNG = EURLNGSt.iloc[19,4] + 480000 + sum(EURLNGSt.iloc[21:24,4])
ITplLNG = sum(EURLNGSt.iloc[34:37,4])

n_BZN = 4
Country = np.array(["United Kingdom", "Belgium", "Netherlands", "France", "Germany", "Italy"])
oplLNGNG = np.array([GBoplLNGNG, BEoplLNGNG, NLoplLNGNG, FRoplLNGNG, DEoplLNGNG, IToplLNGNG])*0.00558278
ucLNG = np.array([GBucLNG, BEucLNG, NLucLNG, FRucLNG, DEucLNG, ITucLNG])*0.00558278
plLNG = np.array([GBplLNG, BEplLNG, NLplLNG, FRplLNG, DEplLNG, ITplLNG])*0.00558278

# create plLNGot
fig, ax = plt.subplots()
fig.set_figheight(4)
fig.set_figwidth(7)

#index = np.arange(n_BZN)
bar_width = 0.2
opacity = 0.8

plt.bar(Country, oplLNGNG, color='darkblue', label='Operational')
plt.bar(Country, ucLNG, bottom=oplLNGNG, color='mediumblue', label='Under Construction')
plt.bar(Country, plLNG, bottom=oplLNGNG+ucLNG, color='lightblue', label='Planned')

plt.ylabel("Working Gas Volume Equivalent [GWh]")
plt.title("Liquid Natural Gas Storage Capacity Oct. 2022")

plt.legend()

plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')
plt.ylim(0, 14000)

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

plt.tight_layout()
plt.show()

# %%
EMix = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\EnergyMix.csv")

gFEMix = EMix.loc[EMix["Continent"] == "Europe"].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Variable"] == "Gas"].loc[EMix["Unit"] == "TWh"]
gFEMix = gFEMix.sort_values("Area", ascending=True)
gFEMix = gFEMix.reset_index()
del gFEMix['index']

print(gFEMix)
# Out:
#                         Area Country code  Year Area type Continent  \
# 0                    Austria          AUT  2021   Country    Europe
# 1                    Belarus          BLR  2021   Country    Europe
# 2                    Belgium          BEL  2021   Country    Europe
# 3         Bosnia Herzegovina          BIH  2021   Country    Europe
# 4                   Bulgaria          BGR  2021   Country    Europe
# 5                    Croatia          HRV  2021   Country    Europe
# 6                     Cyprus          CYP  2021   Country    Europe
# 7                    Czechia          CZE  2021   Country    Europe
# 8                    Denmark          DNK  2021   Country    Europe
# 9                    Estonia          EST  2021   Country    Europe
# 10       Faroe Islands (the)          FRO  2021   Country    Europe
# 11                   Finland          FIN  2021   Country    Europe
# 12                    France          FRA  2021   Country    Europe
# 13                   Germany          DEU  2021   Country    Europe
# 14                    Greece          GRC  2021   Country    Europe
# 15                   Hungary          HUN  2021   Country    Europe
# 16                   Ireland          IRL  2021   Country    Europe
# 17                     Italy          ITA  2021   Country    Europe
# 18                    Latvia          LVA  2021   Country    Europe
# 19                 Lithuania          LTU  2021   Country    Europe
# 20                Luxembourg          LUX  2021   Country    Europe
# 21                     Malta          MLT  2021   Country    Europe
# 22                   Moldova          MDA  2021   Country    Europe
# 23                Montenegro          MNE  2021   Country    Europe
# 24               Netherlands          NLD  2021   Country    Europe
# 25           North Macedonia          MKD  2021   Country    Europe
# 26                    Norway          NOR  2021   Country    Europe
# 27                    Poland          POL  2021   Country    Europe
# 28                  Portugal          PRT  2021   Country    Europe
# 29                   Romania          ROU  2021   Country    Europe
# 30  Russian Federation (the)          RUS  2021   Country    Europe
# 31                    Serbia          SRB  2021   Country    Europe
# 32                  Slovakia          SVK  2021   Country    Europe
# 33                  Slovenia          SVN  2021   Country    Europe
# 34                     Spain          ESP  2021   Country    Europe
# 35                    Sweden          SWE  2021   Country    Europe
# 36               Switzerland          CHE  2021   Country    Europe
# 37                   Ukraine          UKR  2021   Country    Europe
# 38            United Kingdom          GBR  2021   Country    Europe
#
#    Ember region   EU  OECD  G20   G7                Category Subcategory  \
# 0        Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 1        Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 2        Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 3        Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 4        Europe  1.0   0.0  0.0  0.0  Electricity generation        Fuel
# 5        Europe  1.0   0.0  0.0  0.0  Electricity generation        Fuel
# 6        Europe  1.0   0.0  0.0  0.0  Electricity generation        Fuel
# 7        Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 8        Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 9        Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 10       Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 11       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 12       Europe  1.0   1.0  1.0  1.0  Electricity generation        Fuel
# 13       Europe  1.0   1.0  1.0  1.0  Electricity generation        Fuel
# 14       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 15       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 16       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 17       Europe  1.0   1.0  1.0  1.0  Electricity generation        Fuel
# 18       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 19       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 20       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 21       Europe  1.0   0.0  0.0  0.0  Electricity generation        Fuel
# 22       Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 23       Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 24       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 25       Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 26       Europe  0.0   1.0  0.0  0.0  Electricity generation        Fuel
# 27       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 28       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 29       Europe  1.0   0.0  0.0  0.0  Electricity generation        Fuel
# 30       Europe  0.0   0.0  1.0  0.0  Electricity generation        Fuel
# 31       Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 32       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 33       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 34       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 35       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel
# 36       Europe  0.0   1.0  0.0  0.0  Electricity generation        Fuel
# 37       Europe  0.0   0.0  0.0  0.0  Electricity generation        Fuel
# 38       Europe  0.0   1.0  1.0  1.0  Electricity generation        Fuel
#
#    Variable Unit   Value  YoY absolute change  YoY % change
# 0       Gas  TWh   10.62                 0.67          6.73
# 1       Gas  TWh   36.78                 2.19          6.33
# 2       Gas  TWh   22.52                -4.26        -15.91
# 3       Gas  TWh    0.00                 0.00           NaN
# 4       Gas  TWh    3.05                 0.76         33.19
# 5       Gas  TWh    3.10                -0.34         -9.88
# 6       Gas  TWh    0.00                 0.00           NaN
# 7       Gas  TWh    7.31                 0.44          6.40
# 8       Gas  TWh    1.54                 0.36         30.51
# 9       Gas  TWh    0.04                 0.01         33.33
# 10      Gas  TWh    0.00                 0.00           NaN
# 11      Gas  TWh    3.83                -0.16         -4.01
# 12      Gas  TWh   33.36                -1.92         -5.44
# 13      Gas  TWh   95.22                -1.16         -1.20
# 14      Gas  TWh   22.49                 3.26         16.95
# 15      Gas  TWh    9.65                 0.56          6.16
# 16      Gas  TWh   15.16                -1.08         -6.65
# 17      Gas  TWh  144.01                10.31          7.71
# 18      Gas  TWh    2.13                 0.05          2.40
# 19      Gas  TWh    1.22                -0.48        -28.24
# 20      Gas  TWh    0.17                -0.01         -5.56
# 21      Gas  TWh    1.91                 0.07          3.80
# 22      Gas  TWh    2.50                 0.16          6.84
# 23      Gas  TWh    0.00                 0.00           NaN
# 24      Gas  TWh   56.66               -15.89        -21.90
# 25      Gas  TWh    1.14                 0.00          0.00
# 26      Gas  TWh    0.29                -1.31        -81.88
# 27      Gas  TWh   15.82                -1.47         -8.50
# 28      Gas  TWh   15.57                -2.03        -11.53
# 29      Gas  TWh    9.91                 0.45          4.76
# 30      Gas  TWh  466.24                27.46          6.26
# 31      Gas  TWh    0.51                 0.00          0.00
# 32      Gas  TWh    4.37                 0.80         22.41
# 33      Gas  TWh    0.52                -0.06        -10.34
# 34      Gas  TWh   71.50                 1.76          2.52
# 35      Gas  TWh    0.29                 0.19        190.00
# 36      Gas  TWh    0.00                 0.00           NaN
# 37      Gas  TWh    9.76                -4.43        -31.22
# 38      Gas  TWh  123.58                12.36         11.11

# %%
GEBE = gFEMix.iloc[2, 14]
GEDK = gFEMix.iloc[8, 14]
GEFR = gFEMix.iloc[12, 14]
GEDE = gFEMix.iloc[13, 14]
GEIE = gFEMix.iloc[16, 14]
GEIT = gFEMix.iloc[17, 14]
GENL = gFEMix.iloc[24, 14]
GENO = gFEMix.iloc[26, 14]
GEPL = gFEMix.iloc[27, 14]
GEUK = gFEMix.iloc[38, 14]

GCBE = 18367*9769.44/1000000
GCDK = 2815*9769.44/1000000
GCFR = 42004*9769.44/1000000
GCDE = 94043*9769.44/1000000
GCIE = 5214*9769.44/1000000
GCIT = 76400*9769.44/1000000
GCNL = 42333*9769.44/1000000
GCNO = 5521*9769.44/1000000
GCPL = 23542*9769.44/1000000
GCUK = 77626*9769.44/1000000

# data to plot
n_BZN = 10
GElec = (GEBE, GEDK, GEFR, GEDE, GEIE, GEIT, GENL, GENO, GEPL, GEUK)
GCons = (GCBE, GCDK, GCFR, GCDE, GCIE, GCIT, GCNL, GCNO, GCPL, GCUK)

# create plot
fig, ax = plt.subplots()
fig.set_figheight(4)
fig.set_figwidth(7)

index = np.arange(n_BZN)
bar_width = 0.4
opacity = 0.8

rects1 = plt.bar(index - bar_width/2, GElec, bar_width,
alpha=opacity,
color='lightblue',
label='Gas-based Electricity Generation')

rects2 = plt.bar(index + bar_width/2, GCons, bar_width,
alpha=opacity,
color='darkblue',
label='Total Gas Consumption')

plt.xlabel('Country')
plt.ylabel('Annual Gas Demand [TWh]')
plt.title('Gas Consumption in European Countries 2021')
plt.xticks(index, ('BE', 'DK', 'FR', 'DE', 'IE', 'IT', 'NL', 'NO', 'PL', 'UK'))
plt.legend()

plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

print(GEBE)
print(GCBE)

plt.tight_layout()
plt.show()
# Out:
# 22.52
# 179.43530448
