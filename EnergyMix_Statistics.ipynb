# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

EMix = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\EnergyMix.csv")

FEMix = EMix.loc[EMix["Continent"] == "Europe"].loc[EMix["Year"] == 2021].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Unit"] == "TWh"]
FEMix = FEMix.reset_index()
del FEMix['index']

print(FEMix.to_string())
# Out:
#                          Area Country code  Year Area type Continent Ember region   EU  OECD  G20   G7                Category Subcategory          Variable Unit   Value  YoY absolute change  YoY % change
# 0                     Austria          AUT  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel         Bioenergy  TWh    4.48                -0.11         -2.40
# 1                     Austria          AUT  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel              Coal  TWh    0.14                -0.42        -75.00
# 2                     Austria          AUT  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel               Gas  TWh   10.62                 0.67          6.73
# ...

# %%
pFEMix = EMix.loc[EMix["Continent"] == "Europe"].loc[EMix["Year"] == 2021].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Unit"] == "%"]
pFEMix = pFEMix.reset_index()
del pFEMix['index']

print(pFEMix.to_string())
# Out:
#                          Area Country code  Year Area type Continent Ember region   EU  OECD  G20   G7                Category Subcategory          Variable Unit  Value  YoY absolute change  YoY % change
# 0                     Austria          AUT  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel         Bioenergy    %   6.69                  NaN           NaN
# 1                     Austria          AUT  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity generation        Fuel              Coal    %   0.21                  NaN           NaN
# 2                       Malta          MLT  2021   Country    Europe       Europe  1.0   0.0  0.0  0.0  Electricity generation        Fuel               Gas    %  88.02                  NaN           NaN
# ...

# %%
# Norway
NOEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[239:248,12],
    "Annual Generation [TWh]": FEMix.iloc[239:248,14]})

NOEMix["Annual Generation [%]"] = pFEMix.iloc[239:248,14].round(2)
NOEMix.iloc[2,2] = pFEMix.iloc[295,14].round(2)

NOEMix = NOEMix.reset_index()
del NOEMix['index']
print(NOEMix)

# Netherlands
NLEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[221:230,12],
    "Annual Generation [TWh]": FEMix.iloc[221:230,14]})

NLEMix["Annual Generation [%]"] = pFEMix.iloc[221:230,14].round(2)
NLEMix.iloc[2,2] = pFEMix.iloc[38,14].round(2)

NLEMix = NLEMix.reset_index()
del NLEMix['index']
print(NLEMix)

# Belgium
BEEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[18:27,12],
    "Annual Generation [TWh]": FEMix.iloc[18:27,14]})

BEEMix["Annual Generation [%]"] = pFEMix.iloc[18:27,14].round(2)
BEEMix.iloc[2,2] = pFEMix.iloc[142,14].round(2)

BEEMix = BEEMix.reset_index()
del BEEMix['index']
print(BEEMix)

# France
FREMix = pd.DataFrame({"Fuel Source": FEMix.iloc[108:117,12],
    "Annual Generation [TWh]": FEMix.iloc[108:117,14]})

FREMix["Annual Generation [%]"] = pFEMix.iloc[108:117,14].round(2)
FREMix.iloc[2,2] = pFEMix.iloc[241,14].round(2)

FREMix = FREMix.reset_index()
del FREMix['index']
print(FREMix)

# Republic of Ireland
IEEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[149:158,12],
    "Annual Generation [TWh]": FEMix.iloc[149:158,14]})

IEEMix["Annual Generation [%]"] = pFEMix.iloc[149:158,14].round(2)
IEEMix.iloc[2,2] = pFEMix.iloc[29,14].round(2)

IEEMix = IEEMix.reset_index()
del IEEMix['index']
print(IEEMix)
# Out:
#         Fuel Source  Annual Generation [TWh]  Annual Generation [%]
# 0         Bioenergy                     0.24                   0.16
# 1              Coal                     0.04                   0.03
# 2               Gas                     0.29                   0.19
# 3             Hydro                   138.66                  91.73
# 4           Nuclear                     0.00                   0.00
# 5      Other Fossil                     0.36                   0.24
# 6  Other Renewables                     0.22                   0.15
# 7             Solar                     0.03                   0.02
# 8              Wind                    11.32                   7.49
#         Fuel Source  Annual Generation [TWh]  Annual Generation [%]
# 0         Bioenergy                    10.88                   8.95
# 1              Coal                    14.56                  11.97
# 2               Gas                    56.66                  46.59
# ...

# %%
# %store -r UKEGSdata
UKEMix = pd.DataFrame({"Fuel Source": ["Bioenergy", "Coal", "Gas", "Hydro", "Nuclear", 
                                      "Other Fossil", "Other Renewables", "Solar", "Wind"]})

BiGenTWh = sum(UKEGSdata.iloc[10, 93:97])
CoGenTWh = sum(UKEGSdata.iloc[0, 93:97])
GaGenTWh = sum(UKEGSdata.iloc[2, 93:97])
HyGenTWh = sum(UKEGSdata.iloc[4, 93:97])
NuGenTWh = sum(UKEGSdata.iloc[3, 93:97])
OtFoGenTWh = sum(UKEGSdata.iloc[1, 93:97]) + sum(UKEGSdata.iloc[11, 93:97]) # Note that this includes "Other fuels" since this includes e.g. non-biodegradable wastes bioenergy #G
OtReGenTWh = sum(UKEGSdata.iloc[8, 93:97]) + sum(UKEGSdata.iloc[12, 93:97]) # Note that this includes "Shoreline wave / tidal" and "Pumped storage"
SoGenTWh = sum(UKEGSdata.iloc[9, 93:97])
WiGenTWh = sum(UKEGSdata.iloc[5, 93:97])

ToGenTWh = BiGenTWh + CoGenTWh + GaGenTWh + HyGenTWh + NuGenTWh + OtFoGenTWh + OtReGenTWh + SoGenTWh + WiGenTWh

UKEMix["Annual Generation [TWh]"] = pd.DataFrame({"Annual Generation [TWh]": [BiGenTWh, CoGenTWh, GaGenTWh, HyGenTWh, 
                                                                              NuGenTWh, OtFoGenTWh, OtReGenTWh, SoGenTWh, WiGenTWh]})
UKEMix["Annual Generation [%]"] = UKEMix["Annual Generation [TWh]"]/ToGenTWh*100
UKEMix["Annual Generation [TWh]"] = UKEMix["Annual Generation [TWh]"].round(2)
UKEMix["Annual Generation [%]"] = UKEMix["Annual Generation [%]"].round(2)

print(UKEMix)
# Out:
#         Fuel Source  Annual Generation [TWh]  Annual Generation [%]
# 0         Bioenergy                    39.88                  12.92
# 1              Coal                     6.52                   2.11
# 2               Gas                   123.17                  39.91
# 3             Hydro                     5.50                   1.78
# 4           Nuclear                    45.90                  14.87
# 5      Other Fossil                     8.99                   2.91
# 6  Other Renewables                     1.90                   0.62
# 7             Solar                    12.14                   3.93
# 8              Wind                    64.66                  20.95

# %%
# Sweden
SEEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[320:329,12],
    "Annual Generation [TWh]": FEMix.iloc[320:329,14]})

SEEMix["Annual Generation [%]"] = pFEMix.iloc[320:329,14].round(2)
SEEMix.iloc[2,2] = pFEMix.iloc[304,14].round(2)

SEEMix = SEEMix.reset_index()
del SEEMix['index']
print(SEEMix)

#Denmark
DKEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[72:81,12],
    "Annual Generation [TWh]": FEMix.iloc[72:81,14]})

DKEMix["Annual Generation [%]"] = pFEMix.iloc[72:81,14].round(2)
DKEMix.iloc[2,2] = pFEMix.iloc[259,14].round(2)

DKEMix = DKEMix.reset_index()
del DKEMix['index']
print(DKEMix)

# Switzerland
CHEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[329:338,12],
    "Annual Generation [TWh]": FEMix.iloc[329:338,14]})

CHEMix["Annual Generation [%]"] = pFEMix.iloc[329:338,14].round(2)
CHEMix.iloc[2,2] = pFEMix.iloc[349,14].round(2)

CHEMix = CHEMix.reset_index()
del CHEMix['index']
print(CHEMix)

# Poland
PLEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[248:257,12],
    "Annual Generation [TWh]": FEMix.iloc[248:257,14]})

PLEMix["Annual Generation [%]"] = pFEMix.iloc[248:257,14].round(2)
PLEMix.iloc[2,2] = pFEMix.iloc[205,14].round(2)

PLEMix = PLEMix.reset_index()
del PLEMix['index']
print(PLEMix)

DEEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[117:126,12],
    "Annual Generation [TWh]": FEMix.iloc[117:126,14]})

DEEMix["Annual Generation [%]"] = pFEMix.iloc[117:126,14].round(2)
DEEMix.iloc[2,2] = pFEMix.iloc[169,14].round(2)

DEEMix = DEEMix.reset_index()
del DEEMix['index']
print(DEEMix)

ITEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[158:167,12],
    "Annual Generation [TWh]": FEMix.iloc[158:167,14]})

ITEMix["Annual Generation [%]"] = pFEMix.iloc[158:167,14].round(2)
ITEMix.iloc[2,2] = pFEMix.iloc[20,14].round(2)

ITEMix = ITEMix.reset_index()
del ITEMix['index']
print(ITEMix)

ESEMix = pd.DataFrame({"Fuel Source": FEMix.iloc[311:320,12],
    "Annual Generation [TWh]": FEMix.iloc[311:320,14]})

ESEMix["Annual Generation [%]"] = pFEMix.iloc[311:320,14].round(2)
ESEMix.iloc[2,2] = pFEMix.iloc[133,14].round(2)

ESEMix = ESEMix.reset_index()
del ESEMix['index']
print(ESEMix)
# Out:
#         Fuel Source  Annual Generation [TWh]  Annual Generation [%]
# 0         Bioenergy                    13.08                   7.61
# 1              Coal                     0.01                   0.01
# 2               Gas                     0.29                   0.17
# 3             Hydro                    73.89                  43.02
# 4           Nuclear                    52.97                  30.84
# 5      Other Fossil                     2.76                   1.61
# 6  Other Renewables                     0.00                   0.00
# 7             Solar                     1.53                   0.89
# 8              Wind                    27.24                  15.86
#         Fuel Source  Annual Generation [TWh]  Annual Generation [%]
# 0         Bioenergy                     8.72                  26.38
# 1              Coal                     4.37                  13.22
# 2               Gas                     1.54                   4.66
# ...

# %%
fig, ((ax1, ax2, ax3, ax4, ax5), (ax6, ax7, ax8, ax9, ax10)) = plt.subplots(2, 5, figsize=(12,5), sharex=True)

#fig.suptitle("Energy Mix in the UK and its Neighbours")



FuMi = ["Bioenergy", "Coal", "Gas", "Hydro", "Nuclear", "Other Fossil", "Other Renewables", "Solar", "Wind"]
UKAnGeTWh = UKEMix["Annual Generation [%]"]
NOAnGeTWh = NOEMix["Annual Generation [%]"]
NLAnGeTWh = NLEMix["Annual Generation [%]"]
BEAnGeTWh = BEEMix["Annual Generation [%]"]
FRAnGeTWh = FREMix["Annual Generation [%]"]
IEAnGeTWh = IEEMix["Annual Generation [%]"]
SEAnGeTWh = SEEMix["Annual Generation [%]"]
DKAnGeTWh = DKEMix["Annual Generation [%]"]
ESAnGeTWh = ESEMix["Annual Generation [%]"]
DEAnGeTWh = DEEMix["Annual Generation [%]"]

ax1.barh(FuMi, UKAnGeTWh, color = "navy")
ax2.barh(FuMi, NOAnGeTWh, color = "firebrick")
bar3 = ax3.barh(FuMi, NLAnGeTWh, color = "darkorange")
bar4 = ax4.barh(FuMi, BEAnGeTWh, color = "black")
bar5 = ax5.barh(FuMi, FRAnGeTWh, color = "orchid")
bar6 = ax6.barh(FuMi, IEAnGeTWh, color = "mediumseagreen")
bar7 = ax7.barh(FuMi, SEAnGeTWh, color = "deepskyblue")
bar8 = ax8.barh(FuMi, DKAnGeTWh, color = "lightcoral")
bar9 = ax9.barh(FuMi, ESAnGeTWh, color = "grey")
bar10 = ax10.barh(FuMi, DEAnGeTWh, color = "brown")

plt.suptitle("Contribution of Fuel Sources to Electricity Mix in Select Countries")

ax1.set_title("United Kingdom")
ax2.set_title("Norway")
ax3.set_title("The Netherlands")
ax4.set_title("Belgium")
ax5.set_title("France")
ax6.set_title("Republic of Ireland")
ax7.set_title("Sweden")
ax8.set_title("Denmark")
ax9.set_title("Spain")
ax10.set_title("Germany")

ax5.set_xlabel("Relative Contribution to National Electricity Generation [%]")
    
for ax in fig.get_axes():
    ax.minorticks_on()
    ax.label_outer()
    ax.grid(visible=True, which='major', color='0.65', linestyle='-')
    ax.grid(visible=True, which='minor', color='0.65', linestyle=':')
    

for bars in ax1.containers:
    ax1.bar_label(bars, padding=1)

for bars in ax2.containers:
    ax2.bar_label(bars, padding=1)
    
for bars in ax3.containers:
    ax3.bar_label(bars, padding=1)
    
for bars in ax4.containers:
    ax4.bar_label(bars, padding=1)
    
for bars in ax5.containers:
    ax5.bar_label(bars, padding=1)
    
for bars in ax6.containers:
    ax6.bar_label(bars, padding=1)
    
for bars in ax7.containers:
    ax7.bar_label(bars, padding=1)
    
for bars in ax8.containers:
    ax8.bar_label(bars, padding=1)
    
for bars in ax9.containers:
    ax9.bar_label(bars, padding=1)
    
for bars in ax10.containers:
    ax10.bar_label(bars, padding=1)
    
ax8.set_xlabel("Contribution to Domestic Generation Mix [%]                               ")
 
ax.set_xlim(0,100)

plt.tight_layout()
plt.show()

# %%
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(10,3), sharex=True)

#fig.suptitle("Energy Mix in the UK and its Neighbours")

FuMi = ["Bioenergy", "Coal", "Gas", "Hydro", "Nuclear", "Other Fossil", "Other Renewables", "Solar", "Wind"]
SEAnGeTWh = SEEMix["Annual Generation [%]"]
CHAnGeTWh = CHEMix["Annual Generation [%]"]
PLAnGeTWh = PLEMix["Annual Generation [%]"]
ESAnGeTWh = ESEMix["Annual Generation [%]"]

ax1.barh(FuMi, SEAnGeTWh, color = "blue")
ax2.barh(FuMi, CHAnGeTWh, color = "red")
#ax2.barh(FuMi, ESAnGeTWh, color = "grey")
ax3.barh(FuMi, PLAnGeTWh, color = "red")

ax1.set_title("Sweden")
ax2.set_title("Switzerland")
#ax2.set_title("Spain")
ax3.set_title("Poland")

ax1.set_xlabel("Electricity Generation Contribution [%]")
ax2.set_xlabel("Electricity Generation Contribution [%]")
ax3.set_xlabel("Electricity Generation Contribution [%]")

for bars in ax1.containers:
    ax1.bar_label(bars, padding=1)

for bars in ax2.containers:
    ax2.bar_label(bars, padding=1)
    
for bars in ax3.containers:
    ax3.bar_label(bars, padding=1)
    
for ax in fig.get_axes():
    ax.label_outer()
    ax.grid(visible=True, which='major', color='0.65', linestyle='-')
    ax.grid(visible=True, which='minor', color='0.65', linestyle=':')
    
ax.set_xlim(0,100)

plt.tight_layout()
plt.show()

# %%
dFEMix = EMix.loc[EMix["Continent"] == "Europe"].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity demand"].loc[EMix["Subcategory"] == "Demand"].loc[EMix["Unit"] == "TWh"]
dFEMix = dFEMix.reset_index()
dFEMix = dFEMix.drop([14], axis=0)
dFEMix = dFEMix.reset_index()
del dFEMix['index']
del dFEMix['level_0']

print(dFEMix.to_string())

fFEMix = EMix.loc[EMix["Continent"] == "Europe"].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity imports"]
fFEMix = fFEMix.reset_index()
fFEMix = fFEMix.drop([14], axis=0)
fFEMix = fFEMix.reset_index()
del fFEMix['index']
del fFEMix['level_0']

print(fFEMix.to_string())

gFEMix = EMix.loc[EMix["Continent"] == "Europe"].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Variable"] == "Gas"].loc[EMix["Unit"] == "%"]
gFEMix = gFEMix.sort_values("Area", ascending=True)
gFEMix = gFEMix.reset_index()
del gFEMix['index']

print(gFEMix.to_string())
# Out:
#                         Area Country code  Year Area type Continent Ember region   EU  OECD  G20   G7            Category Subcategory Variable Unit    Value  YoY absolute change  YoY % change
# 0                    Austria          AUT  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity demand      Demand   Demand  TWh    74.49                 3.10          4.34
# 1                    Belarus          BLR  2021   Country    Europe       Europe  0.0   0.0  0.0  0.0  Electricity demand      Demand   Demand  TWh    43.57                 7.86         22.01
# 2                    Belgium          BEL  2021   Country    Europe       Europe  1.0   1.0  0.0  0.0  Electricity demand      Demand   Demand  TWh    91.15                 3.59          4.10
# 3         Bosnia Herzegovina          BIH  2021   Country    Europe       Europe  0.0   0.0  0.0  0.0  Electricity demand      Demand   Demand  TWh    12.62                 0.94          8.05
# ...

# %%
eFEMix = pd.DataFrame({"Country": dFEMix.iloc[:,0],
    "Annual Demand [TWh]": dFEMix.iloc[:,14]})
eFEMix["Gas Generation [%]"] = gFEMix.iloc[:,14]
eFEMix["Annual Imports [TWh]"] = fFEMix.iloc[:,14]
eFEMix["Import Dependance [%]"] = round(fFEMix.iloc[:,14]/dFEMix.iloc[:,14]*100, 2)



eFEMix = eFEMix.replace(np.NaN, 0)

eFEMix = eFEMix.reset_index()
del eFEMix['index']
print(eFEMix)
# Out:
#                      Country  Annual Demand [TWh]  Gas Generation [%]  \
# 0                    Austria                74.49               15.86
# 1                    Belarus                43.57               83.84
# 2                    Belgium                91.15               22.74
# 3         Bosnia Herzegovina                12.62                0.00
# 4                   Bulgaria                38.52                6.45
# 5                    Croatia                19.08               20.50
# 6                     Cyprus                 5.12                0.00
# 7                    Czechia                72.65                8.73
# 8                    Denmark                37.93                4.66
# 9                    Estonia                 9.82                0.56
# 10       Faroe Islands (the)                 0.42                0.00
# 11                   Finland                89.31                5.35
# ...

# %%
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(10,7), sharex=True)

ax1.barh(eFEMix["Country"], eFEMix["Gas Generation [%]"])
ax2.barh(eFEMix["Country"], eFEMix["Import Dependance [%]"])

ax1.set_title("Gas Generation")
ax2.set_title("Import Dependance")

ax1.set_xlabel("Gas Generation Contribution [%]")
ax2.set_xlabel("Import Dependance on Demand [%]")
    
for ax in fig.get_axes():
    ax.label_outer()
    ax.grid(visible=True, which='major', color='0.65', linestyle='-')
    ax.grid(visible=True, which='minor', color='0.65', linestyle=':')

ax2.set_xlim(0,100)
#    ax2.set_xlim(-50,50)
    
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(10)

plt.title('European Countries by Electricity Import Dependance')
plt.xlabel('Gas Generation Contribution')

# Plot individual data series one by one

x = [-100, 100]

plt.fill_between(x, 100000000, color = "mistyrose")
plt.fill_between(x, -100000000, color = "lightblue")

ax.bar(eFEMix["Country"], eFEMix["Import Dependance [%]"])



# Set gridline styles
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

print(ax.get_xlim())
print(ax.get_ylim())

# Format the labels on the x-axis
plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(-1, 39)
plt.ylim(-50, 100)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# (-2.34, 40.339999999999996)
# (-43.721, 88.301)

# %%
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(10)

plt.title('European Countries by Electricity Import Dependance')
plt.xlabel('Gas Generation Contribution')

# Plot individual data series one by one

ax.bar(eFEMix["Country"], eFEMix["Import Dependance [%]"])



# Set gridline styles
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

print(ax.get_xlim())
print(ax.get_ylim())

# Format the labels on the x-axis
plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(-1, 39)
plt.ylim(-50, 100)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# (-2.34, 40.339999999999996)
# (-43.721, 88.301)
