# %% [markdown]
# This is where I started importing the data for 2021 which I already have in a xlsx file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BZGBDA2021 = pd.read_excel(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\BZ_GB_20210101-20211231.xlsx", sheet_name='NordPool ASA GB')

#Date = pd.date_range(start="1/1/2021", periods=365, freq="D")

#|

#Date =  pd.date_range(start="1/1/2021", periods=365, freq="D")

BZGBDA2021data = pd.DataFrame({"BZN|GB 2021": BZGBDA2021.iloc[0:365,2]})
BZGBDA2021data["Date"] = pd.date_range(start="1/1/2021", periods=365, freq="D")

BZGBDA2021data["BZN|GB 2021"] = BZGBDA2021data["BZN|GB 2021"].replace(to_replace=",", value=".", regex=True)

NewOrder = ["Date", "BZN|GB 2021"]

BZGBDA2021data["BZN|GB 2021"] = BZGBDA2021data["BZN|GB 2021"].round(2)

#BZGBDAdata["Date"] = pd.date_range(start="1/1/2021", periods=365, freq="D")
BZGBDA2021data = BZGBDA2021data.reindex(columns=NewOrder)
BZGBDA2021data
# Out:
#           Date  BZN|GB 2021
# 0   2021-01-01        68.40
# 1   2021-01-02        71.54
# 2   2021-01-03        65.27
# 3   2021-01-04        67.32
# 4   2021-01-05        67.40
# ..         ...          ...
# 360 2021-12-27       218.84
# 361 2021-12-28       211.31
# 362 2021-12-29       216.81
# 363 2021-12-30       138.12
# 364 2021-12-31       142.70
#
# [365 rows x 2 columns]

# %% [markdown]
# This is where I imported the data for 2022. I had to stack these cells together. This is the data I captured on the Nord Pool ASA website.

# %%
BZGBDA2022 = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\BZ_GB_20220101-20221231.csv")

BZGBDA2022 = BZGBDA2022.replace('-', np.NaN)

print(BZGBDA2022)
#BZGBDA2021data = pd.DataFrame({"BZN|GB": BZGBDA2021.iloc[0:365,2]})
#BZGBDA2021data["Date"] = pd.date_range(start="1/1/2021", periods=365, freq="D")

#NewOrder = ["Date", "BZN|GB"]

#BZGBDAdata["Date"] = pd.date_range(start="1/1/2021", periods=365, freq="D")
#BZGBDA2021data = BZGBDA2021data.reindex(columns=NewOrder)
#BZGBDA2021data

#BZGBDA2022data = pd.DataFrame({"BZN|GB": BZGBDA2022.iloc[0:,4] BZGBDA2022.iloc[0:,3]})
#BZGBDA2022data

#BZGBDA2022data = pd.DataFrame(BZGBDA2022.stack()) #.reset_index()
#BZGBDA2022data = BZGBDA2022.stack(level = ["Jan-22", "Feb-22"])

BZGBDA2022data = pd.concat([BZGBDA2022['Jan-22'], BZGBDA2022['Feb-22'], BZGBDA2022['Mar-22'], BZGBDA2022['Apr-22'], BZGBDA2022['May-22'], BZGBDA2022['Jun-22'], BZGBDA2022['Jul-22'], BZGBDA2022['Aug-22'], BZGBDA2022['Sep-22'], BZGBDA2022['Oct-22'], BZGBDA2022['Nov-22'], BZGBDA2022['Dec-22']], ignore_index=True).to_frame("BZN|GB 2022")
BZGBDA2022data = BZGBDA2022data.dropna()
BZGBDA2022data["Date"] = pd.date_range(start="1/1/2022", periods=365, freq="D")

BZGBDA2022data["BZN|GB 2022"] = BZGBDA2022data["BZN|GB 2022"].replace(to_replace=",", value=".", regex=True)

NewOrder = ["Date", "BZN|GB 2022"]

#BZGBDAdata["Date"] = pd.date_range(start="1/1/2021", periods=365, freq="D")
BZGBDA2022data = BZGBDA2022data.reindex(columns=NewOrder)

BZGBDA2022data.reset_index(drop=True, inplace=True)
BZGBDA2022data
# Out:
#     Unnamed: 0  Day  Jan-23  Dec-22  Nov-22  Oct-22  Sep-22  Aug-22  Jul-22  \
# 0            0    1  105,63  399,44  101,31  115,19  468,00  356,04  253,32
# 1            1    2  184,86  376,87   80,85  193,63  368,70  276,56  187,84
# 2            2    3  160,58  304,23  112,02  243,12  300,07  293,31  200,73
# 3            3    4  121,00  304,71  185,97  188,84  274,37  313,54  197,79
# 4            4    5  145,05  341,62  130,87  134,88  326,48  332,03  255,44
# 5            5    6  122,14  367,66  117,93   88,23  375,31  302,67  264,18
# 6            6    7  118,64  358,56  105,35  122,84  331,04  272,57  225,12
# 7            7    8   88,78  422,30   94,11  174,38  310,17  331,19  268,21
# 8            8    9  137,08  438,01  127,38  136,38  325,46  340,08  233,82
# 9            9   10  139,21  364,42   96,95  163,19  361,53  323,49  222,47
# 10          10   11  111,69  377,75   82,72  213,13  373,76  341,04  320,15
# ...

# %% [markdown]
# Here I simply stacked the data from 2021 together with that from 2022.

# %%
BZGBDA = pd.concat([BZGBDA2021data["BZN|GB 2021"], BZGBDA2022data["BZN|GB 2022"]], ignore_index=True).to_frame("BZN|GB")

BZGBDA["Date"] = pd.date_range(start="1/1/2021", periods=730, freq="D")

NewOrder = ["Date", "BZN|GB"]

#BZGBDAdata["Date"] = pd.date_range(start="1/1/2021", periods=365, freq="D")
BZGBDA = BZGBDA.reindex(columns=NewOrder)
BZGBDA.iloc[:,1] = BZGBDA.iloc[:,1].astype(float)

print(BZGBDA.to_string())
# Out:
#           Date  BZN|GB
# 0   2021-01-01   68.40
# 1   2021-01-02   71.54
# 2   2021-01-03   65.27
# 3   2021-01-04   67.32
# 4   2021-01-05   67.40
# 5   2021-01-06  160.07
# 6   2021-01-07  101.79
# 7   2021-01-08  115.46
# 8   2021-01-09   74.13
# 9   2021-01-10   76.47
# 10  2021-01-11   71.51
# 11  2021-01-12  126.26
# 12  2021-01-13  223.40
# 13  2021-01-14  191.17
# 14  2021-01-15  173.73
# 15  2021-01-16   67.59
# 16  2021-01-17   67.43
# 17  2021-01-18   68.38
# 18  2021-01-19   68.13
# 19  2021-01-20   65.85
# 20  2021-01-21   64.85
# 21  2021-01-22   72.82
# 22  2021-01-23   72.79
# 23  2021-01-24   84.96
# 24  2021-01-25   70.93
# 25  2021-01-26   78.02
# 26  2021-01-27   77.82
# 27  2021-01-28   66.01
# 28  2021-01-29   66.95
# 29  2021-01-30   70.17
# 30  2021-01-31   68.86
# 31  2021-02-01   91.34
# 32  2021-02-02   65.49
# 33  2021-02-03   64.02
# 34  2021-02-04   65.08
# 35  2021-02-05   65.86
# 36  2021-02-06   66.19
# 37  2021-02-07   53.77
# 38  2021-02-08   60.73
# ...

# %%
sta = 468 
end = 499

FMin = min(BZGBDA.iloc[sta:end, 1])
FMax = max(BZGBDA.iloc[sta:end, 1])

print("Min: ", FMin, "      Max: ", FMax)
# Out:
# Min:  73.75       Max:  226.3

# %% [markdown]
# Ignore this plot below. This was where I tested the plotting.

# %%
from matplotlib.ticker import MultipleLocator

# Set the figure size
plt.figure(figsize=(16,10))

# plotting the points 
plt.plot(BZGBDA["Date"], BZGBDA["BZN|GB"], label="GB DA Price")

plt.ylabel('DA Price [EUR/MWh]')

#ax = plt.plot()
#ax.xaxis.set_major_locator(MultipleLocator())
#ax.xaxis.set_minor_locator(MultipleLocator(4))

plt.legend()
plt.title('GB DA Price')
plt.grid()

plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=90, ha='center')
plt.tight_layout()   # <- helps to maintain non-overlapping

plt.minorticks_off()


#plt.xticks(np.arange(Quarter[43,2]), np.arange(Quarter[43,98]), step=4)

#ax.xaxis.set_minor_locator(MultipleLocator())
#ax.xaxis.set_major_locator(MultipleLocator(5))

#ax.grid(True, which='both', axis='both')

plt.show()

# %%
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

print(type(BZGBDA["BZN|GB"]))

# %store -r BZGBpc2

fig, ax = plt.subplots()
#fig.set_figheight(8)
#fig.set_figwidth(10)

plt.title('Electricity Day-Ahead Price of Great Britain (GB)')
plt.ylabel('Day-Ahead Electricity Price [EUR/MWh]')

plt.fill_between(BZGBDA["Date"], BZGBDA["BZN|GB"].astype(float), color="navy")
ax.plot(BZGBDA["Date"], BZGBDA["BZN|GB"], color = "navy", label="2021 - 2022 GB DAEP")
ax.plot(BZGBDA["Date"], BZGBpc2["Mean DAEP [EUR/MWh]"].rolling(28,  center=True).mean(), linewidth = 3, color = "red", label="2017 - 2019 Rolling Average")
ax.plot(BZGBDA["Date"], BZGBDA["BZN|GB"].rolling(28,  center=True).mean(), linewidth=3, color = "gold", label="2021 - 2022 Rolling Average")

plt.legend()
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#n = 30
#ax.xaxis.set_minor_locator(plt.MultipleLocator(n-3))
#ax.xaxis.set_major_locator(plt.MultipleLocator(n))
ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

#fig.autofmt_xdate()

plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(18628, 19358)
plt.ylim(0, 800)
plt.tight_layout()

ax.xaxis.set_minor_locator(mdates.MonthLocator())
ax.xaxis.set_minor_formatter(mdates.DateFormatter(""))

plt.show()
print(ax.get_xlim())
# Out:
# <class 'pandas.core.series.Series'>
# (18628.0, 19358.0)

# %%
BZGB = BZGBDA

# %store BZGB
del BZGB
# Out:
# Stored 'BZGB' (DataFrame)
