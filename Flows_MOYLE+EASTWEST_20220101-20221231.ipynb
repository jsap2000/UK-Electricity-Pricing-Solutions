# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

MEW2022 = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\Flows_MOYLE+EASTWEST_20220101-20221231.csv")

MEW2022 = MEW2022.replace('n/e', np.NaN)
MEW2022 = MEW2022.replace('N/A', np.NaN)
#MEW2022 = MEW2022.replace(np.NaN, 0)

MEW2022 = {'Time (CET/CEST)': MEW2022.iloc[:,0],'BZN|IE(SEM) > BZN|GB [MW]': MEW2022.iloc[:,1],'BZN|GB > BZN|IE(SEM) [MW]': MEW2022.iloc[:,2]}

MEW2022['BZN|IE(SEM) > BZN|GB [MW]'] = pd.to_numeric(MEW2022['BZN|IE(SEM) > BZN|GB [MW]'], errors='coerce')
MEW2022['BZN|GB > BZN|IE(SEM) [MW]'] = pd.to_numeric(MEW2022['BZN|GB > BZN|IE(SEM) [MW]'], errors='coerce')

MEW2022 = pd.DataFrame(MEW2022)

MEW2022.iloc[2288, 1:] = 0
MEW2022.iloc[3833, 1:] = 0

MEW2022.iloc[4257, 1:] = 0
MEW2022.iloc[6845, 1:] = 0

MEW2022.iloc[7135, 1:] = 0
MEW2022.iloc[8760, 1:] = 0

MEW2022['BZN|IE(SEM) > BZN|GB [MW]'] = MEW2022['BZN|IE(SEM) > BZN|GB [MW]'].interpolate().values.ravel().tolist()
MEW2022['BZN|GB > BZN|IE(SEM) [MW]'] = MEW2022['BZN|GB > BZN|IE(SEM) [MW]'].interpolate().values.ravel().tolist()

MEW2022 = pd.DataFrame(MEW2022)
print(MEW2022.to_string())

B = MEW2022.iloc[8760,1]/2
B
# Out:
#                           Time (CET/CEST)  BZN|IE(SEM) > BZN|GB [MW]  BZN|GB > BZN|IE(SEM) [MW]
# 0     01.01.2022 00:00 - 01.01.2022 01:00                 709.000000                   0.000000
# 1     01.01.2022 01:00 - 01.01.2022 02:00                 668.000000                   0.000000
# 2     01.01.2022 02:00 - 01.01.2022 03:00                 728.000000                   0.000000
# 3     01.01.2022 03:00 - 01.01.2022 04:00                 749.000000                   0.000000
# 4     01.01.2022 04:00 - 01.01.2022 05:00                 725.000000                   0.000000
# 5     01.01.2022 05:00 - 01.01.2022 06:00                 609.000000                   0.000000
# 6     01.01.2022 06:00 - 01.01.2022 07:00                 274.000000                   0.000000
# 7     01.01.2022 07:00 - 01.01.2022 08:00                 162.000000                  33.000000
# 8     01.01.2022 08:00 - 01.01.2022 09:00                 225.000000                  78.000000
# ...

# %%
# Python code to find average of each consecutive segment
  
# Importing
import statistics
from itertools import islice
import numpy as np

def function():
    result = []
    for i in range(0, len(MEW2022.iloc[:,0])):
        if i < 85:
            number = i
            start = 24*i
            end = 24*(i+1)-1+1
            day = MEW2022.iloc[start,0]
            operation1 = sum(MEW2022.iloc[start:end,1])
            operation2 = sum(MEW2022.iloc[start:end,2])
            result.append({"Day": day, "BZN|IE(SEM) > BZN|GB [MW]": operation1, "BZN|GB > BZN|IE(SEM) [MW]": operation2})
        elif i == 85:
            number = i
            start = 24*i
            skip = 2041
            end = 2063+1
            day = MEW2022.iloc[start,0]
            operation1 = sum(MEW2022.iloc[start:skip,1]) + sum(MEW2022.iloc[(skip+2):end,1])
            operation2 = sum(MEW2022.iloc[start:skip,2]) + sum(MEW2022.iloc[(skip+2):end,2])
            result.append({"Day": day, "BZN|IE(SEM) > BZN|GB [MW]": operation1, "BZN|GB > BZN|IE(SEM) [MW]": operation2})
        elif 86 <= i < 302:
            number = i
            start = 24*i
            end = 24*(i+1)-1+1
            day = MEW2022.iloc[start,0]
            operation1 = sum(MEW2022.iloc[start:end,1])
            operation2 = sum(MEW2022.iloc[start:end,2])
            result.append({"Day": day, "BZN|IE(SEM) > BZN|GB [MW]": operation1, "BZN|GB > BZN|IE(SEM) [MW]": operation2})
        elif i == 302:
            number = i
            start = 24*i
            skip = 7249
            end = 7272+1
            day = MEW2022.iloc[start,0]
            operation1 = sum(MEW2022.iloc[start:skip,1]) + sum(MEW2022.iloc[(skip+2):end,1])
            operation2 = sum(MEW2022.iloc[start:skip,2]) + sum(MEW2022.iloc[(skip+2):end,2])
            result.append({"Day": day, "BZN|IE(SEM) > BZN|GB [MW]": operation1, "BZN|GB > BZN|IE(SEM) [MW]": operation2})
        elif 303 <= i < 365:
            number = i
            start = 24*i+1
            end = 24*(i+1)-1+2
            day = MEW2022.iloc[start,0]
            operation1 = sum(MEW2022.iloc[start:end,1])
            operation2 = sum(MEW2022.iloc[start:end,2])
            result.append({"Day": day, "BZN|IE(SEM) > BZN|GB [MW]": operation1, "BZN|GB > BZN|IE(SEM) [MW]": operation2})
    df = pd.DataFrame(result, columns=['Day','BZN|IE(SEM) > BZN|GB [MW]', 'BZN|GB > BZN|IE(SEM) [MW]'])
    return df
print(function().to_string())
# Out:
#                                      Day  BZN|IE(SEM) > BZN|GB [MW]  BZN|GB > BZN|IE(SEM) [MW]
# 0    01.01.2022 00:00 - 01.01.2022 01:00                6277.000000                 860.000000
# 1    02.01.2022 00:00 - 02.01.2022 01:00                3925.000000                1252.000000
# 2    03.01.2022 00:00 - 03.01.2022 01:00                4596.000000                1669.000000
# 3    04.01.2022 00:00 - 04.01.2022 01:00                1853.000000                6226.000000
# 4    05.01.2022 00:00 - 05.01.2022 01:00                 183.000000               14730.000000
# 5    06.01.2022 00:00 - 06.01.2022 01:00               10976.000000                  35.000000
# 6    07.01.2022 00:00 - 07.01.2022 01:00                6483.000000                2222.000000
# 7    08.01.2022 00:00 - 08.01.2022 01:00               12579.000000                   0.000000
# 8    09.01.2022 00:00 - 09.01.2022 01:00                9961.000000                3136.000000
# ...

# %%
MEW2022 = function()
print(MEW2022.to_string())

# %store MEW2022
del MEW2022
# Out:
#                                      Day  BZN|IE(SEM) > BZN|GB [MW]  BZN|GB > BZN|IE(SEM) [MW]
# 0    01.01.2022 00:00 - 01.01.2022 01:00                6277.000000                 860.000000
# 1    02.01.2022 00:00 - 02.01.2022 01:00                3925.000000                1252.000000
# 2    03.01.2022 00:00 - 03.01.2022 01:00                4596.000000                1669.000000
# 3    04.01.2022 00:00 - 04.01.2022 01:00                1853.000000                6226.000000
# 4    05.01.2022 00:00 - 05.01.2022 01:00                 183.000000               14730.000000
# 5    06.01.2022 00:00 - 06.01.2022 01:00               10976.000000                  35.000000
# 6    07.01.2022 00:00 - 07.01.2022 01:00                6483.000000                2222.000000
# 7    08.01.2022 00:00 - 08.01.2022 01:00               12579.000000                   0.000000
# 8    09.01.2022 00:00 - 09.01.2022 01:00                9961.000000                3136.000000
# ...
