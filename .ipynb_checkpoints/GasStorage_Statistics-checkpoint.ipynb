# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

EURGAS = pd.read_excel(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\GasStorageEurope.xlsx", sheet_name="WGV and No by status")



# Select the rows data should be taken from
EURGAS = EURGAS.iloc[:,0:5].copy()
EURGAS = EURGAS.round(2)
EURGAS = EURGAS.replace(np.NaN, 0)

print(EURGAS.to_string())
# Out:
#    Country / Status / WGV (TWh)  operational  under construction  planned    TOTAL
# 0                       Austria        95.19                0.00     0.00    95.19
# 1                       Belgium         9.00                0.00     0.00     9.00
# 2                      Bulgaria         5.80                0.00     4.75    10.55
# 3                       Croatia         5.22                0.00     0.28     5.50
# 4                Czech Republic        43.13                0.84     0.43    44.41
# 5                       Denmark        10.46                0.00     0.00    10.46
# 6                        France       132.30                0.00     4.10   136.40
# 7                       Germany       260.53                0.00     5.90   266.42
# 8                        Greece         0.00                0.00     3.86     3.86
# 9                       Hungary        69.63                0.00     0.00    69.63
# 10                        Italy       195.37                8.59    40.75   244.70
# 11                       Latvia        24.20                0.00     0.00    24.20
# 12                  Netherlands       144.56                0.00     0.00   144.56
# 13                       Poland        38.43                0.69     9.00    48.12
# 14                     Portugal         3.57                0.00     0.00     3.57
# 15                      Romania        32.99                0.00    12.53    45.52
# 16                     Slovakia        43.45                0.00     3.61    47.05
# 17                        Spain        34.25                0.00     0.00    34.25
# 18                       Sweden         0.09                0.00     0.00     0.09
# 19                           EU      1148.16               10.12    85.21  1243.48
# 20                      Belarus        15.32                5.52     0.00    20.83
# 21           Russian Federation        23.82                0.00     0.00    23.82
# 22                       Serbia         4.53                0.00     0.00     4.53
# 23                       Turkey        35.02                0.00    43.24    78.26
# 24                      Ukraine       327.92                0.00     0.00   327.92
# 25               United Kingdom        17.47                0.38    35.34    53.19
# 26                 Total non EU       424.09                5.89    78.58   508.56
# 27                 TOTAL EUROPE      1572.25               16.01   163.79  1752.05

# %%
#EMix.loc[EURGAS["Country / Status / WGV (TWh)"] == "United Kingdom"].loc[EMix["Year"] == 2021].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Unit"] == "TWh"]

GBop = EURGAS.iloc[25,1]
NLop = EURGAS.iloc[12,1]
BEop = EURGAS.iloc[1,1]
FRop = EURGAS.iloc[6,1]
DEop = EURGAS.iloc[7,1]
ITop = EURGAS.iloc[10,1]

GBuc = EURGAS.iloc[25,2]
NLuc = EURGAS.iloc[12,2]
BEuc = EURGAS.iloc[1,2]
FRuc = EURGAS.iloc[6,2]
DEuc = EURGAS.iloc[7,2]
ITuc = EURGAS.iloc[10,2]

GBpl = EURGAS.iloc[25,3]
NLpl = EURGAS.iloc[12,3]
BEpl = EURGAS.iloc[1,3]
FRpl = EURGAS.iloc[6,3]
DEpl = EURGAS.iloc[7,3]
ITpl = EURGAS.iloc[10,3]

n_BZN = 4
Country = np.array(["United Kingdom", "Netherlands", "Belgium", "France", "Germany", "Italy"])
op = np.array([GBop, NLop, BEop, FRop, DEop, ITop])
uc = np.array([GBuc, NLuc, BEuc, FRuc, DEuc, ITuc])
pl = np.array([GBpl, NLpl, BEpl, FRpl, DEpl, ITpl])

# create plot
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(8)

#index = np.arange(n_BZN)
bar_width = 0.2
opacity = 0.8

plt.bar(Country, op, color='darkblue', label='Operational')
plt.bar(Country, uc, bottom=op, color='mediumblue', label='Under Construction')
plt.bar(Country, pl, bottom=op+uc, color='lightblue', label='Planned')

plt.ylabel("Working Gas Volume Equivalent [TWh]")
plt.title("Gaseous Natural Gas Storage Capacity Jul. 2021")

plt.legend()

plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')
plt.ylim(0, 300)

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

EURLNG = pd.read_excel(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\LNGStorageEurope.xlsx", sheet_name="Import Terminals")

EURLNGSt = pd.DataFrame()

# Select the rows data should be taken from
EURLNGSt["Country"] = EURLNG.iloc[2:72,0]
EURLNGSt["Status"] = EURLNG.iloc[2:72,3]
EURLNGSt["Commenced"] = EURLNG.iloc[2:72,5]
EURLNGSt["Type"] = EURLNG.iloc[2:72,6]
EURLNGSt["Storage [m3]"] = EURLNG.iloc[2:72,11]
#EURLNGSt = EURLNG.round(2)

EURLNGSt = EURLNGSt.replace(np.NaN, 0)
EURLNGSt = EURLNGSt.reset_index()
del EURLNGSt["index"]

print(EURLNGSt.to_string())
# Out:
#            Country                 Status Commenced                                    Type   Storage [m3]
# 0          Albania                planned      2023                                    FSRU              0
# 1          Belgium            operational      1987                           large onshore         566000
# 2          Belgium     under construction      2024                           large onshore              0
# 3          Belgium     under construction      2026                           large onshore              0
# 4          Croatia            operational      2021                                    FSRU         140000
# 5          Croatia                planned      2029                                    FSRU         140000
# 6           Cyprus     under construction      2023                                    FSRU         137000
# 7            Egypt              suspended         w                                    FSRU              0
# 8            Egypt            operational      2015                                    FSRU         170000
# 9          Estonia                planned      2025                           large onshore         160000
# 10         Estonia                planned         0                           large onshore         160000
# 11         Finland                planned      2023                                    FSRU         151000
# 12          France            operational      2016                           large onshore         600000
# 13          France            operational      2010                           large onshore         330000
# 14          France                planned      2022                           large onshore              0
# 15          France                planned      2030                           large onshore              0
# 16          France            operational      1972                           large onshore          80000
# 17          France            operational      1980                           large onshore         360000
# 18          France                planned         0                                    FSRU              0
# 19         Germany                planned      2023                           large onshore         330000
# 20         Germany                planned      2026                           large onshore  up to 480 000
# 21         Germany                planned      2023                                    FSRU         263000
# 22         Germany                planned      2025                                    FSRU              0
# 23         Germany                planned      2023                                    FSRU         170000
# 24          Greece                planned      2023                                    FSRU              0
# 25          Greece     under construction      2023                                    FSRU         153500
# 26          Greece                planned         0                                    FSRU         170000
# 27          Greece            operational      1999                           large onshore         225000
# 28          Greece                planned      2024                                    FSRU         170000
# 29         Ireland                planned         0                                    FSRU              0
# 30         Ireland                planned      2024                                    FSRU              0
# 31          Israel            operational      2013                                    FSRU         138000
# 32           Italy            operational      2013                                    FSRU         137500
# 33           Italy            operational      1971                           large onshore         100000
# 34           Italy                planned      2023                                    FSRU              0
# 35           Italy                planned      2024                                    FSRU              0
# 36           Italy                planned         0                           large onshore         320000
# 37           Italy            operational      2009  offshore GBS (Gravity Based Structure)         250000
# 38          Latvia                planned      2023                FRU + direct link to UGS              0
# 39       Lithuania            operational      2014                                    FSRU         170000
# 40           Malta            operational      2017            FSU + onshore regasification         125000
# 41         Morocco                planned         0                           large onshore              0
# 42         Morocco                planned      2025                                    FSRU              0
# 43     Netherlands            operational      2011                           large onshore         540000
# 44     Netherlands     under construction      2023                           large onshore              0
# 45     Netherlands                planned      2025                           large onshore         180000
# 46     Netherlands            operational      2022                                    FSRU         180000
# 47          Poland                planned      2025                                    FSRU         170000
# 48          Poland            operational      2016                           large onshore         320000
# 49          Poland     under construction      2023                           large onshore         180000
# 50        Portugal            operational      2004                           large onshore         390000
# 51          Russia            operational      2019                                    FSRU              0
# 52           Spain            operational      1969                           large onshore         760000
# 53           Spain            operational      2003                           large onshore         450000
# 54           Spain            operational      1989                           large onshore         587000
# 55           Spain  built not operational      2012                           large onshore         300000
# 56           Spain            operational      1988                           large onshore         619500
# 57           Spain            operational      2007                           large onshore         300000
# 58           Spain            operational      2006                           large onshore         600000
# 59          Turkey            operational      2016                                    FSRU         167000
# 60          Turkey            operational      2006                           large onshore         280000
# 61          Turkey                planned      2022                                    FSRU         170000
# 62          Turkey            operational      2018                                    FSRU         170000
# 63          Turkey            operational      1994                           large onshore         255000
# 64  United Kingdom            operational      2005                           large onshore        1000000
# 65  United Kingdom     under construction      2025                           large onshore         200000
# 66  United Kingdom            operational      2009                           large onshore         320000
# 67  United Kingdom            operational      2009                           large onshore         775000
# 68  United Kingdom              suspended      2007                                gas port              0

# %%
print(EURLNGSt.iloc[66,4])
# Out:
# 320000

# %%
#EMix.loc[EURLNGSt["Country / Status / WGV (TWh)"] == "United Kingdom"].loc[EMix["Year"] == 2021].loc[EMix["Year"] == 2021].loc[EMix["Category"] == "Electricity generation"].loc[EMix["Subcategory"] == "Fuel"].loc[EMix["Unit"] == "TWh"]

GBoplLNGNG = EURLNGSt.iloc[64,4] + EURLNGSt.iloc[66,4] + EURLNGSt.iloc[67,4]
NLoplLNGNG = EURLNGSt.iloc[43,4] + EURLNGSt.iloc[46,4]
BEoplLNGNG = EURLNGSt.iloc[1,4]
FRoplLNGNG = EURLNGSt.iloc[12,4] + EURLNGSt.iloc[13,4] + EURLNGSt.iloc[16,4] + EURLNGSt.iloc[17,4]
DEoplLNGNG = 0
IToplLNGNG = EURLNGSt.iloc[32,4] + EURLNGSt.iloc[33,4] + EURLNGSt.iloc[37,4]

GBucLNG = EURLNGSt.iloc[65,4]
NLucLNG = EURLNGSt.iloc[44,4]
BEucLNG = EURLNGSt.iloc[2,4] + EURLNGSt.iloc[3,4]
FRucLNG = 0
DEucLNG = 0
ITucLNG = 0

GBplLNG = 0
NLplLNG = EURLNGSt.iloc[45,4]
BEplLNG = 0
FRplLNG = EURLNGSt.iloc[14,4] + EURLNGSt.iloc[15,4]
DEplLNG = EURLNGSt.iloc[19,4] + 480000 + sum(EURLNGSt.iloc[21:24,4])
ITplLNG = sum(EURLNGSt.iloc[34:37,4])

n_BZN = 4
Country = np.array(["United Kingdom", "Netherlands", "Belgium", "France", "Germany", "Italy"])
oplLNGNG = np.array([GBoplLNGNG, NLoplLNGNG, BEoplLNGNG, FRoplLNGNG, DEoplLNGNG, IToplLNGNG])*0.00558278
ucLNG = np.array([GBucLNG, NLucLNG, BEucLNG, FRucLNG, DEucLNG, ITucLNG])*0.00558278
plLNG = np.array([GBplLNG, NLplLNG, BEplLNG, FRplLNG, DEplLNG, ITplLNG])*0.00558278

# create plLNGot
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(8)

#index = np.arange(n_BZN)
bar_width = 0.2
opacity = 0.8

plt.bar(Country, oplLNGNG, color='darkblue', label='Operational')
plt.bar(Country, ucLNG, bottom=oplLNGNG, color='mediumblue', label='Under Construction')
plt.bar(Country, plLNG, bottom=oplLNGNG+ucLNG, color='lightblue', label='Planned')

plt.ylabel("Working Gas Volume Equivalent [GWh]")
plt.title("Liquid Natural Gas Storage Capacity Oct. 2022")

plt.legend()

plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')
plt.ylim(0, 14000)

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

plt.tight_layout()
plt.show()
