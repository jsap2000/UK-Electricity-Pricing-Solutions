# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Let UKEGS be the UK generation of electricity by source
UKEGS = pd.read_excel(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\ET_5.1_DEC_22.xlsx", sheet_name='Quarter')
UKEGS = UKEGS.replace('[x]', np.NaN)

# Select the rows data should be taken from
UKEGSdata = UKEGS.iloc[69:82,1:].copy()
UKEGSdata.columns = UKEGS.iloc[43,1:].copy()
UKEGSdata.reset_index(drop=True, inplace=True)

# Create an index column to the left
UKEGSdata.columns.name = ""

# Display the UKEGS table
UKEGSdata
# Out:
#                       Fuel Quarter 1 1998 Quarter 2 1998 Quarter 3 1998  \
# 0                     Coal        35.3887        28.5386        27.3078
# 1                      Oil         2.1296         1.7746         2.4213
# 2                      Gas         30.115        26.7426        27.9092
# 3                  Nuclear        25.9566        23.6301        22.9314
# 4    Hydro (natural flow)          1.8733          0.825         0.8579
# 5               Total wind         0.2053         0.2146         0.2249
# 6             Onshore wind            NaN            NaN            NaN
# 7            Offshore wind            NaN            NaN            NaN
# 8   Shoreline wave / tidal            NaN            NaN            NaN
# 9                    Solar            NaN            NaN            NaN
# 10               Bioenergy         0.7713         0.7952         0.8128
# 11             Other fuels         1.5596         0.9068         0.8497
# 12          Pumped storage         0.4576         0.4358         0.4045
#
#    Quarter 4 1998 Quarter 1 1999 Quarter 2 1999 Quarter 3 1999 Quarter 4 1999  \
# 0         31.7357        30.5385        22.5613        22.7798        30.3002
# 1          1.8571         2.0358         1.4602         1.4486         1.6042
# 2         33.0315        36.8365          32.77        33.5824         39.712
# 3         26.9678        26.2404        24.6503        21.5023        22.7399
# 4          1.5614         1.8765         1.0748          0.736         1.6483
# 5          0.2321         0.1992         0.2082         0.2183         0.2253
# 6             NaN            NaN            NaN            NaN            NaN
# 7             NaN            NaN            NaN            NaN            NaN
# 8             NaN            NaN            NaN            NaN            NaN
# 9             NaN            NaN            NaN            NaN            NaN
# 10          0.858         0.9332          0.989          1.021         1.0439
# 11         0.9206         1.5873         0.9229         0.8648          0.937
# 12         0.3257         0.8059         0.6357         0.7935         0.6675
#
#    Quarter 1 2000  ... Quarter 2 2020 Quarter 3 2020 Quarter 4 2020  \
# 0         32.5625  ...         0.3779         0.5317         1.2876
# 1          1.8032  ...         0.2127         0.5185         0.5979
# 2         40.8957  ...        22.6233        30.2602        31.7347
# 3         22.9725  ...        11.8709        10.9309        14.3705
# 4          2.1272  ...         1.0086         1.1838         2.2025
# 5          0.2252  ...        13.3758        14.6821        21.2663
# 6             NaN  ...         6.0857         6.6705         9.2489
# 7             NaN  ...         7.2901         8.0116        12.0174
# 8             NaN  ...         0.0031         0.0034         0.0018
# 9             NaN  ...         5.4296         4.2114         1.3498
# 10         1.0836  ...         9.8975         9.1554         9.9547
# 11          1.116  ...         1.8204         1.7169         1.7141
# 12         0.6954  ...         0.2863         0.3268         0.4993
#
#    Quarter 1 2021 Quarter 2 2021 Quarter 3 2021 Quarter 4 2021 Quarter 1 2022  \
# 0          2.3856         0.7637         1.5091         1.8566         2.4353
# 1          0.4008         0.3383         0.4497          0.562         0.5287
# 2         32.5528        31.0548        29.3591        30.2066        28.1361
# 3         11.5516         11.411        10.6053         12.336        12.4837
# 4          1.7674         1.0011         0.6608         2.0666         1.8731
# 5         21.1621        11.4853        10.1164        21.8983         24.407
# 6          9.9616         5.2953         3.9921         9.9035        11.7968
# 7         11.2005         6.1899         6.1242        11.9948        12.6102
# 8          0.0013         0.0012         0.0013         0.0016         0.0015
# 9          1.7156         4.9967         4.0327          1.393         2.0768
# 10        10.3052         9.7474          9.179        10.6451         9.9667
# 11         1.7993         1.7839          1.707         1.9534         1.9218
# 12         0.4849         0.4302         0.4208         0.5582         0.5886
#
#    Quarter 2 2022 Quarter 3 2022 [provisional]
# 0          0.4785                       1.4991
# 1          0.4208                       0.3591
# 2         32.2577                      34.3271
# 3         12.9767                      10.8607
# 4          0.9354                       0.7222
# 5         16.2715                      13.4717
# 6           7.398                       5.6464
# 7          8.8735                       7.8254
# 8          0.0026                       0.0022
# 9          5.0902                       4.8356
# 10         8.0887                       9.2105
# 11         2.0238                       2.0271
# 12         0.4439                       0.4036
#
# [13 rows x 100 columns]

# %% [markdown]
# The below cell is simply for testing out graphing codes for non-renewable fuels.

# %%
from matplotlib.ticker import MultipleLocator

# Quarter aQuarteris values
Quarter = UKEGS.iloc[43,2:]

# corresponding y aQuarteris values
Coal = UKEGS.iloc[69,2:]
Oil = UKEGS.iloc[70,2:]
Gas = UKEGS.iloc[71,2:]
Nuclear = UKEGS.iloc[72,2:]

# Set the figure size
plt.figure(figsize=(16,10))

# plotting the points 
plt.plot(Quarter, Coal, label="Coal")
plt.plot(Quarter, Oil, label="Oil")
plt.plot(Quarter, Gas, label="Gas")
plt.plot(Quarter, Nuclear, label="Nuclear")

plt.ylabel('Electricity Generated [TWh]')

#ax = plt.plot()
#ax.xaxis.set_major_locator(MultipleLocator())
#ax.xaxis.set_minor_locator(MultipleLocator(4))

plt.legend()
plt.title('Quarterly High-Carbon Intensity Electricity Generation in Great Britain')
plt.grid()


plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=90, ha='center')
plt.tight_layout()   # <- helps to maintain non-overlapping

plt.minorticks_off()


#plt.xticks(np.arange(Quarter[43,2]), np.arange(Quarter[43,98]), step=4)

#ax.xaxis.set_minor_locator(MultipleLocator())
#ax.xaxis.set_major_locator(MultipleLocator(5))

#ax.grid(True, which='both', axis='both')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8664\425181891.py in <module>
#       2
#       3 # Quarter aQuarteris values
# ----> 4 Quarter = UKEGS.iloc[43,2:]
#       5
#       6 # corresponding y aQuarteris values
#
# NameError: name 'UKEGS' is not defined

# %% [markdown]
# This cell here is the one that actually should be used. You can also use this graph in the report.

# %%
import matplotlib.pyplot as plt

# Set x-axis
Quarter = UKEGS.iloc[43,2:]

# Set y-axis data series
Coal = UKEGS.iloc[69,2:]
Oil = UKEGS.iloc[70,2:]
Gas = UKEGS.iloc[71,2:]

# Create a subplot of given dimensions
fig, ax = plt.subplots()
fig.set_figheight(4)
fig.set_figwidth(10)

plt.title('Quarterly High-Carbon Intensity Electricity Generation in Great Britain (GB)')
plt.ylabel('Electricity Generated [TWh]')

# Plot individual data series one by one
ax.plot(Quarter, Gas, label="Gas")
ax.plot(Quarter, Coal, label="Coal")
ax.plot(Quarter, Oil, label="Oil")

plt.legend()

# Set gridline styles
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

# Set the x-axis tick interval and add minor ticks on the y-axis
n = 4
ax.xaxis.set_minor_locator(plt.MultipleLocator(n-3))
ax.xaxis.set_major_locator(plt.MultipleLocator(n))
ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

print(ax.get_xlim())
print(ax.get_ylim())

# Format the labels on the x-axis
plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(0, 98)
plt.ylim(0, 55)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# (-4.9, 102.9)
# (-2.295205, 52.526705)

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# Set x-axis
x = UKEGS.iloc[43,2:]

# corresponding y axis values
Nuclear = UKEGS.iloc[72,2:]
NFH = UKEGS.iloc[73,2:]
TWind = UKEGS.iloc[74,2:]
Tidal = UKEGS.iloc[77,2:]
Solar = UKEGS.iloc[78,2:]
Bioenergy = UKEGS.iloc[79,2:]
PSH = UKEGS.iloc[81,2:]

fig, ax = plt.subplots()
fig.set_figheight(4)
fig.set_figwidth(10)

plt.title('Quarterly Low-Carbon Intensity Electricity Generation in Great Britain (GB)')
plt.ylabel('Electricity Generated [TWh]')

ax.plot(x, TWind, label="Wind")
ax.plot(x, Nuclear, label="Nuclear")
ax.plot(x, Bioenergy, label="Bioenergy")
ax.plot(x, Solar, label="Solar")
ax.plot(x, NFH, label="NFH")
ax.plot(x, PSH, label="PSH")
ax.plot(x, Tidal, label="Tidal")

plt.legend()
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

n = 4
ax.xaxis.set_minor_locator(plt.MultipleLocator(n-3))
ax.xaxis.set_major_locator(plt.MultipleLocator(n))
ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

print(ax.get_xlim())
print(ax.get_ylim())

plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(0, 98)
plt.ylim(0, 30)
plt.tight_layout()

plt.show()
# Out:
# (-4.9, 102.9)
# (-1.3483900000000002, 28.31619)

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# Set x-axis
x = UKEGS.iloc[43,2:]

# corresponding y axis values
TWind = UKEGS.iloc[74,2:]
OnWind = UKEGS.iloc[75,2:]
OffWind = UKEGS.iloc[76,2:]

fig, ax = plt.subplots()
fig.set_figheight(4)
fig.set_figwidth(10)

plt.title('Quarterly Wind Electricity Generation in Great Britain (GB)')
plt.ylabel('Electricity Generated [TWh]')

ax.plot(x, TWind, label="Total Wind")
ax.plot(x, OffWind, label="Offshore Wind")
ax.plot(x, OnWind, label="Onshore Wind")

plt.legend()
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

n = 4
ax.xaxis.set_minor_locator(plt.MultipleLocator(n-3))
ax.xaxis.set_major_locator(plt.MultipleLocator(n))
ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

print(ax.get_xlim())
print(ax.get_ylim())

plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(0, 98)
plt.ylim(0, 30)
plt.tight_layout()

plt.show()
# Out:
# (-4.9, 102.9)
# (-1.105375, 27.595275)

# %%
# %store UKEGSdata
del UKEGSdata
# Out:
# Stored 'UKEGSdata' (DataFrame)
