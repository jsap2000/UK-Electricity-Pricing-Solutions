# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

GasGB = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\GAS_GB_NEW_20210101-20221231.csv")

LRStGB = GasGB.loc[GasGB["Data Item"] == "Storage, Long Range, Stock Levels"]
LRStGB = LRStGB.reset_index()
del LRStGB['index']

MRStGB = GasGB.loc[GasGB["Data Item"] == "Storage, Medium Range, Stock Levels"]
MRStGB = MRStGB.reset_index()
del MRStGB['index']

SRStGB = GasGB.loc[GasGB["Data Item"] == "Storage, Short Range, Stock Levels"]
SRStGB = SRStGB.reset_index()
del SRStGB['index']

LNGStGB = GasGB.loc[GasGB["Data Item"] == "LNG, Daily Aggregated Stock level, D+1"]
LNGStGB = LNGStGB.reset_index()
del LNGStGB['index']

print(LNGStGB.to_string())
# Out:
#            Applicable At Applicable For                               Data Item         Value       Generated Time Quality Indicator
# 0    31/12/2022 15:30:00     31/12/2022  LNG, Daily Aggregated Stock level, D+1  7.102614e+09  31/12/2022 15:30:00                 L
# 1    30/12/2022 15:30:00     30/12/2022  LNG, Daily Aggregated Stock level, D+1  7.443420e+09  30/12/2022 15:30:01                 L
# 2    29/12/2022 15:30:00     29/12/2022  LNG, Daily Aggregated Stock level, D+1  8.096034e+09  29/12/2022 15:30:01                 L
# 3    28/12/2022 15:30:00     28/12/2022  LNG, Daily Aggregated Stock level, D+1  9.120387e+09  28/12/2022 15:30:01                 L
# 4    27/12/2022 15:30:00     27/12/2022  LNG, Daily Aggregated Stock level, D+1  8.990384e+09  27/12/2022 15:30:01                 L
# 5    26/12/2022 15:30:00     26/12/2022  LNG, Daily Aggregated Stock level, D+1  8.971261e+09  26/12/2022 15:30:00                 L
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

GasGB = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\GAS_GB_NEW_20210101-20221231.csv")

LRStorGB = GasGB.loc[GasGB2021["Data Item"] == "Storage, Long Range, Stock Levels"]
LRStorGB = LRStorGB2021.reset_index()
del LRStorGB2021['index']

GMRStorGB2021 = GasGB2021.loc[GasGB2021["Data Item"] == "Storage, Medium Range, Stock Levels"]
GMRStorGB2021 = GMRStorGB2021.reset_index()
del GMRStorGB2021['index']

GSRStorGB2021 = GasGB2021.loc[GasGB2021["Data Item"] == "Storage, Short Range, Stock Levels"]
GSRStorGB2021 = GSRStorGB2021.reset_index()
del GSRStorGB2021['index']

GLNGStorGB2021 = GasGB2021.loc[GasGB2021["Data Item"] == "LNG, Daily Aggregated Stock level, D+1"]
GLNGStorGB2021 = GInStorGB2021.reset_index()
del GInStorGB2021['index']

GasStorGB2021 = pd.DataFrame({"Date": LRStorGB2021.iloc[:,1],
    "Long Range [GWh]": LRStorGB2021.iloc[:,3]})
GasStorGB2021["Medium Range [GWh]"] = GMRStorGB2021.iloc[:,3]
GasStorGB2021["Short Range [GWh]"] = GSRStorGB2021.iloc[:,3]
GasStorGB2021["Storage Injection [?]"] = GInStorGB2021.iloc[:,3]
GasStorGB2021["Storage Withdrawal [?]"] = GWiStorGB2021.iloc[:,3]

GasStorGB2021 = GasStorGB2021.iloc[::-1]
GasStorGB2021 = GasStorGB2021.reset_index()
del GasStorGB2021['index']

print(GasStorGB2021.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3124\1655364425.py in <module>
#       5 GasGB = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\GAS_GB_NEW_20210101-20221231.csv")
#       6
# ----> 7 LRStorGB = GasGB.loc[GasGB2021["Data Item"] == "Storage, Long Range, Stock Levels"]
#       8 LRStorGB = LRStorGB2021.reset_index()
#       9 del LRStorGB2021['index']
#
# NameError: name 'GasGB2021' is not defined

# %%
GasGB2022 = pd.read_csv(r"C:\Users\anton_zpf58tt\OneDrive\Documents\Glasgow\Year 4\ENG4110P Individual Project 4\Code\UK-Electricity-Pricing-Solutions\GAS_GB_20220101-20221231.csv")

GLRStorGB2022 = GasGB2022.loc[GasGB2022["Data Item"] == "Storage, Long Range, Stock Levels"]
GLRStorGB2022 = GLRStorGB2022.reset_index()
del GLRStorGB2022['index']

GMRStorGB2022 = GasGB2022.loc[GasGB2022["Data Item"] == "Storage, Medium Range, Stock Levels"]
GMRStorGB2022 = GMRStorGB2022.reset_index()
del GMRStorGB2022['index']

GSRStorGB2022 = GasGB2022.loc[GasGB2022["Data Item"] == "Storage, Short Range, Stock Levels"]
GSRStorGB2022 = GSRStorGB2022.reset_index()
del GSRStorGB2022['index']

GInStorGB2022 = GasGB2022.loc[GasGB2022["Data Item"] == "Storage Injection, Actual"]
GInStorGB2022 = GInStorGB2022.reset_index()
del GInStorGB2022['index']

GWiStorGB2022 = GasGB2022.loc[GasGB2022["Data Item"] == "Storage Withdrawal, Actual"]
GWiStorGB2022 = GWiStorGB2022.reset_index()
del GWiStorGB2022['index']

GasStorGB2022 = pd.DataFrame({"Date": GLRStorGB2022.iloc[:,1],
    "Long Range [GWh]": GLRStorGB2022.iloc[:,3]})
GasStorGB2022["Medium Range [GWh]"] = GMRStorGB2022.iloc[:,3]
GasStorGB2022["Short Range [GWh]"] = GSRStorGB2022.iloc[:,3]
GasStorGB2022["Short Range [GWh]"] = GasStorGB2022["Short Range [GWh]"].fillna(0)
GasStorGB2022["Storage Injection [?]"] = GInStorGB2022.iloc[:,3]
GasStorGB2022["Storage Withdrawal [?]"] = GWiStorGB2022.iloc[:,3]

GasStorGB2022 = GasStorGB2022.iloc[::-1]
GasStorGB2022 = GasStorGB2022.reset_index()
del GasStorGB2022['index']

print(GasStorGB2022.to_string())

# %%
GasStorGB = pd.DataFrame({"Date": pd.date_range(start="1/1/2021", periods=730, freq="D")})
GasStorGB["Long Range [GWh]"] = pd.concat([GasStorGB2021["Long Range [GWh]"], 
                                           GasStorGB2022["Long Range [GWh]"]], ignore_index=True)
GasStorGB["Medium Range [GWh]"] = pd.concat([GasStorGB2021["Medium Range [GWh]"], 
                                         GasStorGB2022["Medium Range [GWh]"]], ignore_index=True)
GasStorGB["Short Range [GWh]"] = pd.concat([GasStorGB2021["Short Range [GWh]"], 
                                         GasStorGB2022["Short Range [GWh]"]], ignore_index=True)

GasStorGB.iloc[541,2] = np.nanmean(np.array([GasStorGB.iloc[540,2], GasStorGB.iloc[542,2]]))
GasStorGB.iloc[666,1] = np.nanmean(np.array([GasStorGB.iloc[665,1], GasStorGB.iloc[667,1]]))
GasStorGB.iloc[706,1] = np.nanmean(np.array([GasStorGB.iloc[705,1], GasStorGB.iloc[707,1]]))

print(GasStorGB.to_string())

# %%
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

fig, ax = plt.subplots()
#fig.set_figheight(8)
#fig.set_figwidth(10)

plt.title('Gas Storage in the UK')
plt.ylabel('Compound Quantity of Natural Gas Stored [GWh]')

Lo = GasStorGB["Short Range [GWh]"]
LoMe = GasStorGB["Short Range [GWh]"] + GasStorGB["Medium Range [GWh]"]
LoMeSh = GasStorGB["Short Range [GWh]"] + GasStorGB["Medium Range [GWh]"] + GasStorGB["Long Range [GWh]"]

ax.plot(GasStorGB["Date"], LoMeSh, color = "lightblue", label="Long Range")
ax.plot(GasStorGB["Date"], LoMe, color = "mediumblue", label="Medium Range")
ax.plot(GasStorGB["Date"], Lo, color = "darkblue", label="Short Range")

plt.fill_between(GasStorGB["Date"],LoMeSh, color="lightblue")
plt.fill_between(GasStorGB["Date"], LoMe, color="mediumblue")
plt.fill_between(GasStorGB["Date"], Lo, color="darkblue")

ax.plot(GasStorGB["Date"], LoMeSh.rolling(28,  center=True).mean(), linewidth=3, color = "gold", label="Total Rolling Average")

plt.legend()
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(18628, 19358)
plt.ylim(0, 25000)
plt.tight_layout()

ax.xaxis.set_minor_locator(mdates.MonthLocator())
ax.xaxis.set_minor_formatter(mdates.DateFormatter(""))

plt.show()

# %%
GasStorGB2 = pd.DataFrame({"Date": pd.date_range(start="1/1/2021", periods=730, freq="D")})
GasStorGB2["Storage Injection [?]"] = pd.concat([GasStorGB2021["Storage Injection [?]"], GasStorGB2022["Storage Injection [?]"]], ignore_index=True)
GasStorGB2["Storage Withdrawal [?]"] = pd.concat([GasStorGB2021["Storage Withdrawal [?]"], GasStorGB2022["Storage Withdrawal [?]"]], ignore_index=True)

GasStorGB2.iloc[365:369,1] = np.nanmean(np.array([GasStorGB2.iloc[364,1], GasStorGB2.iloc[369,1]]))
GasStorGB2.iloc[365:369,2] = np.nanmean(np.array([GasStorGB2.iloc[364,2], GasStorGB2.iloc[369,2]]))

print(GasStorGB2.to_string())

# %%
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

fig, ax = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(10)

plt.title('Gas Storage Changes in the UK')
plt.ylabel('Compound Quantity of Natural Gas Injected or Withdrawn from Storage [?]')

Mean = GasStorGB2["Storage Injection [?]"] + GasStorGB2["Storage Withdrawal [?]"]

ax.plot(GasStorGB2["Date"], GasStorGB2["Storage Injection [?]"], color = "darkgreen", label="Storage Injections")
ax.plot(GasStorGB2["Date"], GasStorGB2["Storage Withdrawal [?]"], color = "firebrick", label="Storage Withdrawal")

plt.fill_between(GasStorGB2["Date"], GasStorGB2["Storage Injection [?]"], color="darkgreen")
plt.fill_between(GasStorGB2["Date"], GasStorGB2["Storage Withdrawal [?]"], color="firebrick")

ax.plot(GasStorGB2["Date"], Mean.rolling(28,  center=True).mean(), linewidth=3, color = "gold", label="Rolling Average")

plt.legend()
plt.grid(visible=True, which='major', color='0.65', linestyle='-')
plt.grid(visible=True, which='minor', color='0.65', linestyle=':')

ax.yaxis.get_ticklocs(minor=True)
ax.minorticks_on()

plt.tick_params(axis='x', which='major', labelsize=10)
plt.xticks(rotation=45, ha='right')
plt.xlim(18628, 19358)
plt.ylim(-1e9, 1e9)
plt.tight_layout()

ax.xaxis.set_minor_locator(mdates.MonthLocator())
ax.xaxis.set_minor_formatter(mdates.DateFormatter(""))

plt.show()
